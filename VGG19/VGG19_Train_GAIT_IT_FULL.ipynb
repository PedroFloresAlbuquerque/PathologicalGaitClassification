# %%
####### Imports #######
# Directory and file paths processing
# Image processing into 3D arrays
import re
import os
import sys
sys.path.append('/home/pfa/Documents/Code')
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing import image
from sort import sort_nicely
from multiprocessing import Process, Manager
import pickle
# Out:
# Using TensorFlow backend.

# %%
## Get dataset
base_dir = '/home/datasets/GAIT-IT'

sample_count = 0
all_images = []
all_labels = []
subjects_data = {}
train_images = []; train_labels = []
validation_images = []; validation_labels = []
test_images = []; test_labels = []

classes = {'Diplegic' : 0, 'Hemiplegic' : 1, 'Neuropathic' : 2, 'Normal' : 3, 'Parkinson' : 4}
classes_inv = {0 : 'Diplegic', 1 : 'Hemiplegic', 2 : 'Neuropathic', 3 : 'Normal', 4 : 'Parkinson'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:

        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_GEIs_dir = os.path.join(subj_folder_dir, 'SEIs', 'side_view')
        # print(subj_GEIs_dir)

        subj_GEIs_folders = [name for name in os.listdir(subj_GEIs_dir) if os.path.isdir(os.path.join(subj_GEIs_dir, name))]
        sort_nicely(subj_GEIs_folders)

        if subj_folder not in subjects_data: subjects_data[subj_folder] = {}
        subjects_data[subj_folder][pathology] = {}
        subjects_data[subj_folder][pathology]["images"] = []
        subjects_data[subj_folder][pathology]["labels"] = []

        for folder in subj_GEIs_folders:
            # Directory with the GEI images
            subj_pat_lvl_dir = os.path.join(subj_GEIs_dir, folder)
            # print(subj_pat_lvl_dir)
            file_names = os.listdir(subj_pat_lvl_dir)
            sort_nicely(file_names)
            # print(file_names)
            
            # Convert images to numpy arrays, put in batches
            for file_name in file_names:
                file_path = os.path.join(subj_pat_lvl_dir, file_name)
                img = image.load_img(file_path, target_size=(224, 224))
                img_tensor = image.img_to_array(img)
                sample_count += 1
                #all_images.append(img_tensor)
                #all_labels.append(classes[pathology])

                subjects_data[subj_folder][pathology]["images"].append(img_tensor)
                subjects_data[subj_folder][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/GAIT-IT/Diplegic
# /home/datasets/GAIT-IT/Hemiplegic
# /home/datasets/GAIT-IT/Neuropathic
# /home/datasets/GAIT-IT/Normal
# /home/datasets/GAIT-IT/Parkinson

# %%
## Get dataset
base_dir = '/home/datasets/GAIT-IST'

classes = {'diplegic' : 0, 'hemiplegic' : 1, 'neuropathic' : 2, 'normal' : 3, 'parkinsonian' : 4}
classes_inv = {0 : 'diplegic', 1 : 'hemiplegic', 2 : 'neuropathic', 3 : 'normal', 4 : 'parkinsonian'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:
        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_GEIs_dir = os.path.join(subj_folder_dir, 'SGEIs')
        # print(subj_GEIs_dir)

        subj_GEIs_folders = [name for name in os.listdir(subj_GEIs_dir) if os.path.isdir(os.path.join(subj_GEIs_dir, name))]
        sort_nicely(subj_GEIs_folders)

        if subj_folder not in subjects_data: subjects_data[subj_folder] = {}
        subjects_data[subj_folder][pathology] = {}
        subjects_data[subj_folder][pathology]["images"] = []
        subjects_data[subj_folder][pathology]["labels"] = []

        for folder in subj_GEIs_folders:
            # Directory with the GEI images
            subj_pat_lvl_dir = os.path.join(subj_GEIs_dir, folder)
            # print(subj_pat_lvl_dir)
            file_names = os.listdir(subj_pat_lvl_dir)
            sort_nicely(file_names)
            # print(file_names)
            
            # Convert images to numpy arrays, put in batches
            for file_name in file_names:
                file_path = os.path.join(subj_pat_lvl_dir, file_name)
                img = image.load_img(file_path, target_size=(224, 224))
                img_tensor = image.img_to_array(img)
                sample_count += 1
                #all_images.append(img_tensor)
                #all_labels.append(classes[pathology])

                subjects_data[subj_folder][pathology]["images"].append(img_tensor)
                subjects_data[subj_folder][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/GAIT-IST/diplegic
# /home/datasets/GAIT-IST/hemiplegic
# /home/datasets/GAIT-IST/neuropathic
# /home/datasets/GAIT-IST/normal
# /home/datasets/GAIT-IST/parkinsonian

# %%
## Get dataset
base_dir = '/home/datasets/DAI2-GEIs'

classes = {'diplegic' : 0, 'hemiplegic' : 1, 'neuropathic' : 2, 'normal' : 3, 'parkinsonian' : 4}
classes_inv = {0 : 'diplegic', 1 : 'hemiplegic', 2 : 'neuropathic', 3 : 'normal', 4 : 'parkinsonian'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:
        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_pat_lvl_dir = os.path.join(subj_folder_dir, 'GEIs')
        # print(subj_GEIs_dir)

        for subject in ['subject1', 'subject2', 'subject3', 'subject4', 'subject5']:
            if subject in subj_folder:
                subj = subject
                break

        if subj not in subjects_data: subjects_data[subj] = {}
        if pathology not in subjects_data[subj]: 
            subjects_data[subj][pathology] = {}
            subjects_data[subj][pathology]["images"] = []
            subjects_data[subj][pathology]["labels"] = []

        file_names = os.listdir(subj_pat_lvl_dir)
        sort_nicely(file_names)
        #print(file_names)
        
        # Convert images to numpy arrays, put in batches
        for file_name in file_names:
            file_path = os.path.join(subj_pat_lvl_dir, file_name)
            img = image.load_img(file_path, target_size=(224, 224))
            img_tensor = image.img_to_array(img)
            sample_count += 1
            #all_images.append(img_tensor)
            #all_labels.append(classes[pathology])

            subjects_data[subj][pathology]["images"].append(img_tensor)
            subjects_data[subj][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/DAI2-GEIs/diplegic
# /home/datasets/DAI2-GEIs/hemiplegic
# /home/datasets/DAI2-GEIs/neuropathic
# /home/datasets/DAI2-GEIs/normal
# /home/datasets/DAI2-GEIs/parkinsonian

# %%
for subject in sorted(subjects_data.keys()):
    print(subject)

# %%
from keras.utils import to_categorical

def split_data(subjects_data, test_sub):

    # Create training and validation inputs and labels lists
    train_images = []; train_labels = []
    validation_images = []; validation_labels = []
    test_images = []; test_labels = []

    # Iterate through subjects data to fill training and validation sets
    for subject in subjects_data:
        for pathology in subjects_data[subject]:
            if 'sub' in subject and 'subject' not in subject:
                validation_images.extend(subjects_data[subject][pathology]["images"])
                validation_labels.extend(subjects_data[subject][pathology]["labels"])
            elif test_sub in subject:
                test_images.extend(subjects_data[subject][pathology]["images"])
                test_labels.extend(subjects_data[subject][pathology]["labels"])
            else:
                train_images.extend(subjects_data[subject][pathology]["images"])
                train_labels.extend(subjects_data[subject][pathology]["labels"])

    # Convert data lists to arrays
    train_images = np.array(train_images)
    train_labels = np.array(train_labels)
    train_labels = to_categorical(train_labels)
    train = {}
    train["images"] = train_images
    train["labels"] = train_labels

    validation_images = np.array(validation_images)
    validation_labels = np.array(validation_labels)
    validation_labels = to_categorical(validation_labels)
    validation = {}
    validation["images"] = validation_images
    validation["labels"] = validation_labels

    # Check if test set was defined
    try:
        test_images = np.array(test_images)
        test_labels = np.array(test_labels)
        test_labels = to_categorical(test_labels)
        test = {}
        test["images"] = test_images
        test["labels"] = test_labels
    except ValueError:
        print("Test set is empty")
        test = {}
        test["images"] = test_images
        test["labels"] = test_labels

    # Print total sample count and training and validation set counts
    print("Total samples: ", sample_count)
    print(len(train_images))
    print(len(validation_images))
    print(len(test_images))

    return train, validation, test

# %%
# Dense Classifier
from tensorflow.keras import models, layers, optimizers
## Import VGG19 convolutional base
from tensorflow.keras.applications import VGG19

def buildModel():

    # Build de VGG19 Convolutional Network base
    conv_base = VGG19(weights='imagenet',
                      include_top=False,
                      input_shape=(224, 224, 3))

    # Train convolutional blocks 3, 4 and 5
    conv_base.trainable = True

    set_trainable = False
    for layer in conv_base.layers:
        if layer.name == 'block2_conv1':
            set_trainable = True
        if set_trainable:
            layer.trainable = True

    # Build the Fully connected layers of the CNN for classification
    model = models.Sequential()
    model.add(conv_base)
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(5, activation='softmax'))

    model.compile(optimizer=optimizers.SGD(learning_rate=0.0002, momentum=0.9, nesterov=True),
                      loss='categorical_crossentropy',
                      metrics = ['acc'])
    #model.summary()
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_train(k, all_history):

    # Define Model Checkpoint callback
    checkpointer_loss = ModelCheckpoint(filepath='/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/model{}_loss.hdf5'.format(k), verbose=1, save_best_only=True)
    checkpointer_acc = ModelCheckpoint(monitor='val_acc', filepath='/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/model{}_acc.hdf5'.format(k), verbose=1, save_best_only=True)

    CB = []
    CB.append(checkpointer_loss)
    CB.append(checkpointer_acc)

    # Split data into training, validation and test sets
    train, validation, test = split_data(subjects_data=subjects_data, test_sub='subject')
    train_images = train["images"]; train_labels = train["labels"]
    validation_images = validation["images"]; validation_labels = validation["labels"]
    test_images = test["images"]; test_labels = test["labels"]

    # Call model creator
    model = buildModel()

    # Train model using keras.fit
    history = model.fit(train_images, train_labels,
                        epochs=50,
                        batch_size=15,validation_data=(validation_images, validation_labels), callbacks=CB)

    #model.save('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsGEIs/model{}.hdf5'.format(k))
    
    # Update model history with current model for current validation subject
    all_history.append(history.history)

# %%
# Create list to store models history through k-folds iterations for cross validation
all_history = Manager().list()

# Define number iterations for k-folds

# Train model with process to free GPU memory after training
p = Process(target=create_train, args=('FULL_IST_2', all_history))
p.start()
p.join()

# Conver manager list back to normal list
history = [item for item in all_history]

# Store performance history of each fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/all_history_IST_2", 'wb') as f:
    pickle.dump(history,f)
# Out:
# Total samples:  7078
# 5107
# 1540
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 5107 samples, validate on 1540 samples
# Epoch 1/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.0122 - acc: 0.6016
# Epoch 00001: val_loss improved from inf to 0.62791, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_loss.hdf5
#
# Epoch 00001: val_acc improved from -inf to 0.76494, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_acc.hdf5
# 5107/5107 [==============================] - 123s 24ms/sample - loss: 1.0112 - acc: 0.6019 - val_loss: 0.6279 - val_acc: 0.7649
# Epoch 2/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.4324 - acc: 0.8402
# Epoch 00002: val_loss improved from 0.62791 to 0.61113, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_loss.hdf5
#
# Epoch 00002: val_acc did not improve from 0.76494
# 5107/5107 [==============================] - 110s 22ms/sample - loss: 0.4319 - acc: 0.8404 - val_loss: 0.6111 - val_acc: 0.7532
# Epoch 3/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.2629 - acc: 0.9029
# Epoch 00003: val_loss improved from 0.61113 to 0.49928, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_loss.hdf5
#
# Epoch 00003: val_acc improved from 0.76494 to 0.78961, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_acc.hdf5
# 5107/5107 [==============================] - 120s 24ms/sample - loss: 0.2628 - acc: 0.9029 - val_loss: 0.4993 - val_acc: 0.7896
# Epoch 4/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.1834 - acc: 0.9349
# Epoch 00004: val_loss did not improve from 0.49928
#
# Epoch 00004: val_acc did not improve from 0.78961
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.1833 - acc: 0.9350 - val_loss: 0.7837 - val_acc: 0.7500
# Epoch 5/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.1417 - acc: 0.9522
# Epoch 00005: val_loss did not improve from 0.49928
#
# Epoch 00005: val_acc improved from 0.78961 to 0.80974, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_acc.hdf5
# 5107/5107 [==============================] - 111s 22ms/sample - loss: 0.1416 - acc: 0.9522 - val_loss: 0.5746 - val_acc: 0.8097
# Epoch 6/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.1076 - acc: 0.9592
# Epoch 00006: val_loss did not improve from 0.49928
#
# Epoch 00006: val_acc improved from 0.80974 to 0.84221, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_acc.hdf5
# 5107/5107 [==============================] - 111s 22ms/sample - loss: 0.1074 - acc: 0.9593 - val_loss: 0.5053 - val_acc: 0.8422
# Epoch 7/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0950 - acc: 0.9671
# Epoch 00007: val_loss improved from 0.49928 to 0.37682, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_loss.hdf5
#
# Epoch 00007: val_acc improved from 0.84221 to 0.88831, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsSEIs/modelFULL_IST_2_acc.hdf5
# 5107/5107 [==============================] - 122s 24ms/sample - loss: 0.0949 - acc: 0.9671 - val_loss: 0.3768 - val_acc: 0.8883
# Epoch 8/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0599 - acc: 0.9776
# Epoch 00008: val_loss did not improve from 0.37682
#
# Epoch 00008: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0599 - acc: 0.9777 - val_loss: 0.4360 - val_acc: 0.8617
# Epoch 9/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0610 - acc: 0.9765
# Epoch 00009: val_loss did not improve from 0.37682
#
# Epoch 00009: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0609 - acc: 0.9765 - val_loss: 0.4875 - val_acc: 0.8247
# Epoch 10/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0499 - acc: 0.9843
# Epoch 00010: val_loss did not improve from 0.37682
#
# Epoch 00010: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0499 - acc: 0.9843 - val_loss: 0.6020 - val_acc: 0.7948
# Epoch 11/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0447 - acc: 0.9831
# Epoch 00011: val_loss did not improve from 0.37682
#
# Epoch 00011: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0447 - acc: 0.9832 - val_loss: 0.6132 - val_acc: 0.8240
# Epoch 12/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0290 - acc: 0.9894
# Epoch 00012: val_loss did not improve from 0.37682
#
# Epoch 00012: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0290 - acc: 0.9894 - val_loss: 0.7892 - val_acc: 0.8045
# Epoch 13/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0292 - acc: 0.9904
# Epoch 00013: val_loss did not improve from 0.37682
#
# Epoch 00013: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0292 - acc: 0.9904 - val_loss: 0.6093 - val_acc: 0.8448
# Epoch 14/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0297 - acc: 0.9894
# Epoch 00014: val_loss did not improve from 0.37682
#
# Epoch 00014: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0296 - acc: 0.9894 - val_loss: 0.6251 - val_acc: 0.8331
# Epoch 15/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0259 - acc: 0.9908
# Epoch 00015: val_loss did not improve from 0.37682
#
# Epoch 00015: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0259 - acc: 0.9908 - val_loss: 0.5546 - val_acc: 0.8461
# Epoch 16/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0107 - acc: 0.9976
# Epoch 00016: val_loss did not improve from 0.37682
#
# Epoch 00016: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0107 - acc: 0.9977 - val_loss: 0.5869 - val_acc: 0.8610
# Epoch 17/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9945
# Epoch 00017: val_loss did not improve from 0.37682
#
# Epoch 00017: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0125 - acc: 0.9945 - val_loss: 0.6248 - val_acc: 0.8636
# Epoch 18/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0209 - acc: 0.9933
# Epoch 00018: val_loss did not improve from 0.37682
#
# Epoch 00018: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0209 - acc: 0.9933 - val_loss: 0.5830 - val_acc: 0.8643
# Epoch 19/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0068 - acc: 0.9980
# Epoch 00019: val_loss did not improve from 0.37682
#
# Epoch 00019: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0067 - acc: 0.9980 - val_loss: 0.6015 - val_acc: 0.8565
# Epoch 20/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0083 - acc: 0.9971
# Epoch 00020: val_loss did not improve from 0.37682
#
# Epoch 00020: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 0.0083 - acc: 0.9971 - val_loss: 0.6051 - val_acc: 0.8649
# Epoch 21/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0211 - acc: 0.9939
# Epoch 00021: val_loss did not improve from 0.37682
#
# Epoch 00021: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0211 - acc: 0.9939 - val_loss: 0.4993 - val_acc: 0.8630
# Epoch 22/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0104 - acc: 0.9971
# Epoch 00022: val_loss did not improve from 0.37682
#
# Epoch 00022: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0104 - acc: 0.9971 - val_loss: 0.6458 - val_acc: 0.8532
# Epoch 23/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0069 - acc: 0.9982
# Epoch 00023: val_loss did not improve from 0.37682
#
# Epoch 00023: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0069 - acc: 0.9982 - val_loss: 0.6363 - val_acc: 0.8435
# Epoch 24/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 0.0027 - acc: 0.9992
# Epoch 00024: val_loss did not improve from 0.37682
#
# Epoch 00024: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 0.0027 - acc: 0.9992 - val_loss: 0.6524 - val_acc: 0.8597
# Epoch 25/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 9.7935e-04 - acc: 0.9998
# Epoch 00025: val_loss did not improve from 0.37682
#
# Epoch 00025: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 9.7804e-04 - acc: 0.9998 - val_loss: 0.7233 - val_acc: 0.8494
# Epoch 26/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.1852e-04 - acc: 1.0000
# Epoch 00026: val_loss did not improve from 0.37682
#
# Epoch 00026: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 102s 20ms/sample - loss: 2.1823e-04 - acc: 1.0000 - val_loss: 0.6826 - val_acc: 0.8630
# Epoch 27/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.9774e-04 - acc: 1.0000
# Epoch 00027: val_loss did not improve from 0.37682
#
# Epoch 00027: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 101s 20ms/sample - loss: 1.9754e-04 - acc: 1.0000 - val_loss: 0.6798 - val_acc: 0.8656
# Epoch 28/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.8475e-04 - acc: 1.0000
# Epoch 00028: val_loss did not improve from 0.37682
#
# Epoch 00028: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 95s 19ms/sample - loss: 2.8449e-04 - acc: 1.0000 - val_loss: 0.7177 - val_acc: 0.8565
# Epoch 29/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.6627e-04 - acc: 1.0000
# Epoch 00029: val_loss did not improve from 0.37682
#
# Epoch 00029: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.6604e-04 - acc: 1.0000 - val_loss: 0.7593 - val_acc: 0.8578
# Epoch 30/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 6.4585e-05 - acc: 1.0000
# Epoch 00030: val_loss did not improve from 0.37682
#
# Epoch 00030: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 6.4497e-05 - acc: 1.0000 - val_loss: 0.7287 - val_acc: 0.8662
# Epoch 31/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.6483e-04 - acc: 1.0000
# Epoch 00031: val_loss did not improve from 0.37682
#
# Epoch 00031: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.6461e-04 - acc: 1.0000 - val_loss: 0.7924 - val_acc: 0.8584
# Epoch 32/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 7.8265e-05 - acc: 1.0000
# Epoch 00032: val_loss did not improve from 0.37682
#
# Epoch 00032: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 7.8158e-05 - acc: 1.0000 - val_loss: 0.7528 - val_acc: 0.8630
# Epoch 33/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.0075e-04 - acc: 1.0000
# Epoch 00033: val_loss did not improve from 0.37682
#
# Epoch 00033: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.0063e-04 - acc: 1.0000 - val_loss: 0.8032 - val_acc: 0.8519
# Epoch 34/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 9.1135e-05 - acc: 1.0000
# Epoch 00034: val_loss did not improve from 0.37682
#
# Epoch 00034: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 9.1010e-05 - acc: 1.0000 - val_loss: 0.7766 - val_acc: 0.8597
# Epoch 35/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 5.2428e-05 - acc: 1.0000
# Epoch 00035: val_loss did not improve from 0.37682
#
# Epoch 00035: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 5.2356e-05 - acc: 1.0000 - val_loss: 0.7849 - val_acc: 0.8636
# Epoch 36/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.9151e-05 - acc: 1.0000
# Epoch 00036: val_loss did not improve from 0.37682
#
# Epoch 00036: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 2.9112e-05 - acc: 1.0000 - val_loss: 0.7925 - val_acc: 0.8610
# Epoch 37/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.7778e-04 - acc: 1.0000
# Epoch 00037: val_loss did not improve from 0.37682
#
# Epoch 00037: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 2.7740e-04 - acc: 1.0000 - val_loss: 0.7221 - val_acc: 0.8669
# Epoch 38/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 6.5923e-05 - acc: 1.0000
# Epoch 00038: val_loss did not improve from 0.37682
#
# Epoch 00038: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 6.5859e-05 - acc: 1.0000 - val_loss: 0.7242 - val_acc: 0.8740
# Epoch 39/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.8040e-04 - acc: 1.0000
# Epoch 00039: val_loss did not improve from 0.37682
#
# Epoch 00039: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.8016e-04 - acc: 1.0000 - val_loss: 0.8484 - val_acc: 0.8506
# Epoch 40/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.2461e-04 - acc: 1.0000
# Epoch 00040: val_loss did not improve from 0.37682
#
# Epoch 00040: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.2445e-04 - acc: 1.0000 - val_loss: 0.8697 - val_acc: 0.8500
# Epoch 41/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.5043e-04 - acc: 1.0000
# Epoch 00041: val_loss did not improve from 0.37682
#
# Epoch 00041: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 2.5008e-04 - acc: 1.0000 - val_loss: 0.8157 - val_acc: 0.8617
# Epoch 42/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 7.2120e-05 - acc: 1.0000
# Epoch 00042: val_loss did not improve from 0.37682
#
# Epoch 00042: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 7.2023e-05 - acc: 1.0000 - val_loss: 0.8080 - val_acc: 0.8584
# Epoch 43/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 9.4143e-05 - acc: 1.0000
# Epoch 00043: val_loss did not improve from 0.37682
#
# Epoch 00043: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 9.4014e-05 - acc: 1.0000 - val_loss: 0.7920 - val_acc: 0.8571
# Epoch 44/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 5.6896e-05 - acc: 1.0000
# Epoch 00044: val_loss did not improve from 0.37682
#
# Epoch 00044: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 5.6820e-05 - acc: 1.0000 - val_loss: 0.8130 - val_acc: 0.8565
# Epoch 45/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 9.7481e-05 - acc: 1.0000
# Epoch 00045: val_loss did not improve from 0.37682
#
# Epoch 00045: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 9.7348e-05 - acc: 1.0000 - val_loss: 0.7598 - val_acc: 0.8682
# Epoch 46/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 1.0141e-04 - acc: 1.0000
# Epoch 00046: val_loss did not improve from 0.37682
#
# Epoch 00046: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 1.0128e-04 - acc: 1.0000 - val_loss: 0.7867 - val_acc: 0.8623
# Epoch 47/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.6246e-05 - acc: 1.0000
# Epoch 00047: val_loss did not improve from 0.37682
#
# Epoch 00047: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 2.6211e-05 - acc: 1.0000 - val_loss: 0.7877 - val_acc: 0.8643
# Epoch 48/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 2.8356e-05 - acc: 1.0000
# Epoch 00048: val_loss did not improve from 0.37682
#
# Epoch 00048: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 2.8319e-05 - acc: 1.0000 - val_loss: 0.7571 - val_acc: 0.8688
# Epoch 49/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 3.6728e-05 - acc: 1.0000
# Epoch 00049: val_loss did not improve from 0.37682
#
# Epoch 00049: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 3.6693e-05 - acc: 1.0000 - val_loss: 0.8017 - val_acc: 0.8649
# Epoch 50/50
# 5100/5107 [============================>.] - ETA: 0s - loss: 3.6951e-04 - acc: 1.0000
# Epoch 00050: val_loss did not improve from 0.37682
#
# Epoch 00050: val_acc did not improve from 0.88831
# 5107/5107 [==============================] - 94s 18ms/sample - loss: 3.6900e-04 - acc: 1.0000 - val_loss: 0.8572 - val_acc: 0.8468

# %%
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/all_history_IST", 'rb') as f:
    all_history = pickle.load(f)

# %%
## Plot results
print(len(all_history))

average_acc = [np.mean([x["acc"][i] for x in all_history]) for i in range(50)]
average_loss = [np.mean([x["loss"][i] for x in all_history]) for i in range(50)]
average_val_acc = [np.mean([x["val_acc"][i] for x in all_history]) for i in range(50)]
average_val_loss = [np.mean([x["val_loss"][i] for x in all_history]) for i in range(50)]

plt.plot(range(1, len(average_acc) + 1), average_acc, 'bo', label = 'Training acc')
plt.plot(range(1, len(average_val_acc) + 1), average_val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/all_history_IST_2_acc')

plt.figure()

plt.plot(range(1, len(average_loss) + 1), average_loss, 'bo', label = 'Training loss')
plt.plot(range(1, len(average_val_loss) + 1), average_val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/all_history_IST_2_loss')

plt.show()
# Out:
# 1

# %%
# #for i in range(0,10):
# print(np.argmax(all_history[0]['val_acc']))
# print(np.argmin(all_history[0]['val_loss']))
# print(max(all_history[0]['val_acc']))
# print(min(all_history[0]['val_loss']))
print(np.argmin(average_val_loss))
print(np.argmax(average_val_acc))

# %%
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

def evaluate_model(k, confusion_matrices):

    train, validation, test = split_data(subjects_data=subjects_data, test_sub='subject')
    validation_images = validation["images"]; validation_labels = validation["labels"]
    test_images = test["images"]; test_labels = test["labels"]

    # Load best model from checkpoint of current fold
    model = load_model('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/modelsGEIs/model{}.hdf5'.format(k))
    
    # Check validation accuracy
    results = model.evaluate(validation_images, validation_labels)
    print(results)

    predictions = model.predict(validation_images)
    conf_mat = confusion_matrix(np.argmax(validation_labels, axis=1), np.argmax(predictions, axis=1))
    confusion_matrices.append(conf_mat)

# %%
# Load best models of each fold and compute confusion matrices
confusion_matrices = Manager().list()
p = Process(target=evaluate_model, args=('FULL_IST_2_acc', confusion_matrices))
p.start()
p.join()

# Convert manager list back to normal list
conf_matrices = [item for item in confusion_matrices]

# Store list with confusion matrices from every fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/confusion_matrices_IST_2_acc", 'wb') as f:
    pickle.dump(conf_matrices,f)

# Load best models of each fold and compute confusion matrices
confusion_matrices = Manager().list()
p = Process(target=evaluate_model, args=('FULL_IST_2_loss', confusion_matrices))
p.start()
p.join()

# Convert manager list back to normal list
conf_matrices = [item for item in confusion_matrices]

# Store list with confusion matrices from every fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/confusion_matrices_IST_2_loss", 'wb') as f:
    pickle.dump(conf_matrices,f)
# Out:
# Total samples:  7026
# 5055
# 1540
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 431/431 [==============================] - 5s 12ms/sample - loss: 0.8448 - acc: 0.7912
# [0.8448048566755452, 0.7911833]
# Total samples:  7026
# 5055
# 1540
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 431/431 [==============================] - 6s 13ms/sample - loss: 0.7508 - acc: 0.7332
# [0.7508103780085416, 0.7331787]

# %%
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/confusion_matrices_DAI2_acc", 'rb') as f:
    confusion_matrices = pickle.load(f)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Function to display confusion matrices
def DisplayCM(CM, title, save):

    display_labels = ['Diplegic', 'Hemiplegic', 'Neuropathic', 'Normal', 'Parkinson']
    fig, ax = plt.subplots(figsize=(10, 10))
    disp = ConfusionMatrixDisplay(confusion_matrix=CM,
                                display_labels=display_labels)
    disp = disp.plot(include_values=True,
                    cmap='viridis', ax=ax, xticks_rotation='horizontal')
    plt.title(title)
    plt.tight_layout()

    if save: plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_FULL/dataGEIs/Confusion Matrices GEIs/' + title)


# Initialize normalized and average CMs and normalized CMs list
cmAVG = np.zeros((5,5))
cmpercent = np.zeros((5,5))
cmpercentList = []

i = 1
# Create list for eachconfusion matrix in percentages
for cm in confusion_matrices:
    display_labels = ['Diplegic', 'Hemiplegic', 'Neuropathic', 'Normal', 'Parkinson']

    cmpercent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cmpercentList.append(cmpercent)


for i in range(0,5):
    for j in range(0,5):
        cmAVG[i][j] = np.mean([x[i][j] for x in cmpercentList])

# Plot average CM of current model
DisplayCM(CM=cmAVG, title='AVG_IST_2_acc', save=True)

print(cmAVG)
print(np.mean([cmAVG[0][0],cmAVG[1][1], cmAVG[2][2], cmAVG[3][3], cmAVG[4][4]]))
# Out:
# [[0.68041237 0.11340206 0.11340206 0.01030928 0.08247423]
#  [0.12       0.68       0.18       0.         0.02      ]
#  [0.07575758 0.06060606 0.84848485 0.         0.01515152]
#  [0.         0.01960784 0.2745098  0.70588235 0.        ]
#  [0.01709402 0.         0.         0.         0.98290598]]
# 0.7795371110932058
