# %%
####### Imports #######
# Directory and file paths processing
# Image processing into 3D arrays
import re
import os
import sys
sys.path.append('/home/pfa/Documents/Code')
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing import image
from sort import sort_nicely
from multiprocessing import Process, Manager
import pickle
# Out:
# Using TensorFlow backend.

# %%
## Get dataset
base_dir = '/home/datasets/GAIT-IT'

sample_count = 0
all_images = []
all_labels = []
subjects_data = {}
train_images = []; train_labels = []
validation_images = []; validation_labels = []
test_images = []; test_labels = []

classes = {'Diplegic' : 0, 'Hemiplegic' : 1, 'Neuropathic' : 2, 'Normal' : 3, 'Parkinson' : 4}
classes_inv = {0 : 'Diplegic', 1 : 'Hemiplegic', 2 : 'Neuropathic', 3 : 'Normal', 4 : 'Parkinson'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:

        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_GEIs_dir = os.path.join(subj_folder_dir, 'GEIs', 'side_view')
        # print(subj_GEIs_dir)

        subj_GEIs_folders = [name for name in os.listdir(subj_GEIs_dir) if os.path.isdir(os.path.join(subj_GEIs_dir, name))]
        sort_nicely(subj_GEIs_folders)

        if subj_folder not in subjects_data: subjects_data[subj_folder] = {}
        subjects_data[subj_folder][pathology] = {}
        subjects_data[subj_folder][pathology]["images"] = []
        subjects_data[subj_folder][pathology]["labels"] = []

        for folder in subj_GEIs_folders:
            # Directory with the GEI images
            subj_pat_lvl_dir = os.path.join(subj_GEIs_dir, folder)
            # print(subj_pat_lvl_dir)
            file_names = os.listdir(subj_pat_lvl_dir)
            sort_nicely(file_names)
            # print(file_names)
            
            # Convert images to numpy arrays, put in batches
            for file_name in file_names:
                file_path = os.path.join(subj_pat_lvl_dir, file_name)
                img = image.load_img(file_path, target_size=(224, 224))
                img_tensor = image.img_to_array(img)
                sample_count += 1
                #all_images.append(img_tensor)
                #all_labels.append(classes[pathology])

                subjects_data[subj_folder][pathology]["images"].append(img_tensor)
                subjects_data[subj_folder][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/GAIT-IT/Diplegic
# /home/datasets/GAIT-IT/Hemiplegic
# /home/datasets/GAIT-IT/Neuropathic
# /home/datasets/GAIT-IT/Normal
# /home/datasets/GAIT-IT/Parkinson

# %%
## Get dataset
base_dir = '/home/datasets/GAIT-IST'

classes = {'diplegic' : 0, 'hemiplegic' : 1, 'neuropathic' : 2, 'normal' : 3, 'parkinsonian' : 4}
classes_inv = {0 : 'diplegic', 1 : 'hemiplegic', 2 : 'neuropathic', 3 : 'normal', 4 : 'parkinsonian'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:
        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_GEIs_dir = os.path.join(subj_folder_dir, 'GEIs')
        # print(subj_GEIs_dir)

        subj_GEIs_folders = [name for name in os.listdir(subj_GEIs_dir) if os.path.isdir(os.path.join(subj_GEIs_dir, name))]
        sort_nicely(subj_GEIs_folders)

        if subj_folder not in subjects_data: subjects_data[subj_folder] = {}
        subjects_data[subj_folder][pathology] = {}
        subjects_data[subj_folder][pathology]["images"] = []
        subjects_data[subj_folder][pathology]["labels"] = []

        for folder in subj_GEIs_folders:
            # Directory with the GEI images
            subj_pat_lvl_dir = os.path.join(subj_GEIs_dir, folder)
            # print(subj_pat_lvl_dir)
            file_names = os.listdir(subj_pat_lvl_dir)
            sort_nicely(file_names)
            # print(file_names)
            
            # Convert images to numpy arrays, put in batches
            for file_name in file_names:
                file_path = os.path.join(subj_pat_lvl_dir, file_name)
                img = image.load_img(file_path, target_size=(224, 224))
                img_tensor = image.img_to_array(img)
                sample_count += 1
                #all_images.append(img_tensor)
                #all_labels.append(classes[pathology])

                subjects_data[subj_folder][pathology]["images"].append(img_tensor)
                subjects_data[subj_folder][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/GAIT-IST/diplegic
# /home/datasets/GAIT-IST/hemiplegic
# /home/datasets/GAIT-IST/neuropathic
# /home/datasets/GAIT-IST/normal
# /home/datasets/GAIT-IST/parkinsonian

# %%
## Get dataset
base_dir = '/home/datasets/DAI2-GEIs'

classes = {'diplegic' : 0, 'hemiplegic' : 1, 'neuropathic' : 2, 'normal' : 3, 'parkinsonian' : 4}
classes_inv = {0 : 'diplegic', 1 : 'hemiplegic', 2 : 'neuropathic', 3 : 'normal', 4 : 'parkinsonian'}

# %%
## Train GEIs directories

# Sort pathologies, OCD purposes only
pathologies = list(classes.keys())
sort_nicely(pathologies)
for pathology in pathologies:

    pathology_dir = base_dir + '/{}'.format(pathology)
    print(pathology_dir)
    pathology_subj_folders = [name for name in os.listdir(pathology_dir) if os.path.isdir(os.path.join(pathology_dir, name))]
    sort_nicely(pathology_subj_folders)
    
    # /Pathology/subj{i}/GEIs/subj_{i}-pat_{j}-lvl_{k}-{l}_{direction}
    for subj_folder in pathology_subj_folders:
        subj_folder_dir = os.path.join(pathology_dir, subj_folder)
        # print(subj_folder_dir)
        subj_pat_lvl_dir = os.path.join(subj_folder_dir, 'GEIs')
        # print(subj_GEIs_dir)

        for subject in ['subject1', 'subject2', 'subject3', 'subject4', 'subject5']:
            if subject in subj_folder:
                subj = subject
                break

        if subj not in subjects_data: subjects_data[subj] = {}
        if pathology not in subjects_data[subj]: 
            subjects_data[subj][pathology] = {}
            subjects_data[subj][pathology]["images"] = []
            subjects_data[subj][pathology]["labels"] = []

        file_names = os.listdir(subj_pat_lvl_dir)
        sort_nicely(file_names)
        #print(file_names)
        
        # Convert images to numpy arrays, put in batches
        for file_name in file_names:
            file_path = os.path.join(subj_pat_lvl_dir, file_name)
            img = image.load_img(file_path, target_size=(224, 224))
            img_tensor = image.img_to_array(img)
            sample_count += 1
            #all_images.append(img_tensor)
            #all_labels.append(classes[pathology])

            subjects_data[subj][pathology]["images"].append(img_tensor)
            subjects_data[subj][pathology]["labels"].append(classes[pathology])
# Out:
# /home/datasets/DAI2-GEIs/diplegic
# /home/datasets/DAI2-GEIs/hemiplegic
# /home/datasets/DAI2-GEIs/neuropathic
# /home/datasets/DAI2-GEIs/normal
# /home/datasets/DAI2-GEIs/parkinsonian

# %%
for subject in sorted(subjects_data.keys()):
    print(subject)

# %%
from keras.utils import to_categorical

def split_data(subjects_data, test_sub):

    # k = 2*foldIteration - 1

    # # Determine K-folds cross validation subject
    # validation_subjects = ['sub{}'.format(foldIteration), 's{}'.format(k), 's{}'.format(k+1), 's{}'.format(k+2)]
    # print(validation_subjects)

    # Create training and validation inputs and labels lists
    train_images = []; train_labels = []
    validation_images = []; validation_labels = []
    test_images = []; test_labels = []

    # Iterate through subjects data to fill training and validation sets
    for subject in subjects_data:
        for pathology in subjects_data[subject]:
            # if subject == 'validation_subject':
            if 'subject' in subject:
                validation_images.extend(subjects_data[subject][pathology]["images"])
                validation_labels.extend(subjects_data[subject][pathology]["labels"])
            elif subject == test_sub:
                test_images.extend(subjects_data[subject][pathology]["images"])
                test_labels.extend(subjects_data[subject][pathology]["labels"])
            else:
                train_images.extend(subjects_data[subject][pathology]["images"])
                train_labels.extend(subjects_data[subject][pathology]["labels"])

    # Convert data lists to arrays
    train_images = np.array(train_images)
    train_labels = np.array(train_labels)
    train_labels = to_categorical(train_labels)
    train = {}
    train["images"] = train_images
    train["labels"] = train_labels

    validation_images = np.array(validation_images)
    validation_labels = np.array(validation_labels)
    validation_labels = to_categorical(validation_labels)
    validation = {}
    validation["images"] = validation_images
    validation["labels"] = validation_labels

    # # Check if test set was defined
    # try:
    #     test_images = np.array(test_images)
    #     test_labels = np.array(test_labels)
    #     test_labels = to_categorical(test_labels)
    #     test = {}
    #     test["images"] = test_images
    #     test["labels"] = test_labels
    # except ValueError:
    #     print("Test set is empty")
    #     test = {}
    #     test["images"] = test_images
    #     test["labels"] = test_labels

    # Print total sample count and training and validation set counts
    print("Total samples: ", sample_count)
    print(len(train_images))
    print(len(validation_images))
    # print(len(test_images))
    test = {}

    return train, validation, test

# %%
# Dense Classifier
from tensorflow.keras import models, layers, optimizers
## Import VGG19 convolutional base
from tensorflow.keras.applications import VGG19

def buildModel():

    # Build de VGG19 Convolutional Network base
    conv_base = VGG19(weights='imagenet',
                      include_top=False,
                      input_shape=(224, 224, 3))

    # Train convolutional blocks 3, 4 and 5
    conv_base.trainable = True

    set_trainable = False
    for layer in conv_base.layers:
        if layer.name == 'block3_conv1':
            set_trainable = True
        if set_trainable:
            layer.trainable = True

    # Build the Fully connected layers of the CNN for classification
    model = models.Sequential()
    model.add(conv_base)
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(5, activation='softmax'))

    model.compile(optimizer=optimizers.SGD(learning_rate=0.0002, momentum=0.9, nesterov=True),
                      loss='categorical_crossentropy',
                      metrics = ['acc'])
    #model.summary()
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_train(k, all_history):

    # Define Early Stopping checkpoint callback
    ES = EarlyStopping(monitor='val_loss', patience=3)

    # Define Model Checkpoint callback
    checkpointer_loss = ModelCheckpoint(filepath='/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/model{}_loss.hdf5'.format(k), verbose=1, save_best_only=True)
    checkpointer_acc = ModelCheckpoint(monitor= 'val_acc', filepath='/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/model{}_acc.hdf5'.format(k), verbose=1, save_best_only=True)

    CB = []
    CB.append(checkpointer_loss)
    CB.append(checkpointer_acc)

    # Split data into training, validation and test sets
    train, validation, test = split_data(subjects_data=subjects_data, test_sub=None)
    train_images = train["images"]; train_labels = train["labels"]
    validation_images = validation["images"]; validation_labels = validation["labels"]
    # test_images = test["images"]; test_labels = test["labels"]

    # Call model creator
    model = buildModel()

    # Train model using keras.fit
    history = model.fit(train_images, train_labels,
                        epochs=50,
                        batch_size=15, validation_data=(validation_images, validation_labels), callbacks=CB)

    #model.save('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/model{}.hdf5'.format(k))
    
    # Update model history with current model for current validation subject
    all_history.append(history.history)

# %%
# Create list to store models history through k-folds iterations for cross validation
all_history = Manager().list()


# Train model with process to free GPU memory after training
p = Process(target=create_train, args=('FULL', all_history))
p.start()
p.join()


# Conver manager list back to normal list
history = [item for item in all_history]


# Store performance history of each fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/all_history", 'wb') as f:
    pickle.dump(history,f)
# Out:
# Total samples:  7026
# 6595
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 6595 samples, validate on 431 samples
# Epoch 1/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.9718 - acc: 0.6027
# Epoch 00001: val_loss improved from inf to 1.13012, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_loss.hdf5
#
# Epoch 00001: val_acc improved from -inf to 0.57541, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 151s 23ms/sample - loss: 0.9710 - acc: 0.6030 - val_loss: 1.1301 - val_acc: 0.5754
# Epoch 2/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.4461 - acc: 0.8238
# Epoch 00002: val_loss improved from 1.13012 to 0.86145, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_loss.hdf5
#
# Epoch 00002: val_acc improved from 0.57541 to 0.66125, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 147s 22ms/sample - loss: 0.4465 - acc: 0.8237 - val_loss: 0.8614 - val_acc: 0.6613
# Epoch 3/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.2643 - acc: 0.8999
# Epoch 00003: val_loss did not improve from 0.86145
#
# Epoch 00003: val_acc did not improve from 0.66125
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.2644 - acc: 0.8998 - val_loss: 1.1312 - val_acc: 0.6288
# Epoch 4/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.1790 - acc: 0.9371
# Epoch 00004: val_loss did not improve from 0.86145
#
# Epoch 00004: val_acc improved from 0.66125 to 0.68677, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 136s 21ms/sample - loss: 0.1788 - acc: 0.9372 - val_loss: 1.0309 - val_acc: 0.6868
# Epoch 5/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.1410 - acc: 0.9522
# Epoch 00005: val_loss did not improve from 0.86145
#
# Epoch 00005: val_acc did not improve from 0.68677
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.1408 - acc: 0.9522 - val_loss: 1.1518 - val_acc: 0.6613
# Epoch 6/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.1039 - acc: 0.9642
# Epoch 00006: val_loss did not improve from 0.86145
#
# Epoch 00006: val_acc did not improve from 0.68677
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.1038 - acc: 0.9642 - val_loss: 1.3932 - val_acc: 0.6288
# Epoch 7/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0786 - acc: 0.9727
# Epoch 00007: val_loss did not improve from 0.86145
#
# Epoch 00007: val_acc did not improve from 0.68677
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0784 - acc: 0.9727 - val_loss: 1.2908 - val_acc: 0.6752
# Epoch 8/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0612 - acc: 0.9790
# Epoch 00008: val_loss did not improve from 0.86145
#
# Epoch 00008: val_acc did not improve from 0.68677
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0615 - acc: 0.9789 - val_loss: 1.3728 - val_acc: 0.6775
# Epoch 9/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0487 - acc: 0.9809
# Epoch 00009: val_loss did not improve from 0.86145
#
# Epoch 00009: val_acc improved from 0.68677 to 0.73782, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 137s 21ms/sample - loss: 0.0489 - acc: 0.9807 - val_loss: 1.1727 - val_acc: 0.7378
# Epoch 10/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0410 - acc: 0.9865
# Epoch 00010: val_loss did not improve from 0.86145
#
# Epoch 00010: val_acc did not improve from 0.73782
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0410 - acc: 0.9865 - val_loss: 1.1107 - val_acc: 0.7193
# Epoch 11/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0251 - acc: 0.9913
# Epoch 00011: val_loss did not improve from 0.86145
#
# Epoch 00011: val_acc did not improve from 0.73782
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0251 - acc: 0.9914 - val_loss: 1.1519 - val_acc: 0.7309
# Epoch 12/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0372 - acc: 0.9868
# Epoch 00012: val_loss did not improve from 0.86145
#
# Epoch 00012: val_acc did not improve from 0.73782
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0373 - acc: 0.9868 - val_loss: 1.3079 - val_acc: 0.7239
# Epoch 13/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0337 - acc: 0.9874
# Epoch 00013: val_loss did not improve from 0.86145
#
# Epoch 00013: val_acc did not improve from 0.73782
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0336 - acc: 0.9874 - val_loss: 1.5978 - val_acc: 0.6705
# Epoch 14/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0247 - acc: 0.9910
# Epoch 00014: val_loss did not improve from 0.86145
#
# Epoch 00014: val_acc did not improve from 0.73782
# 6595/6595 [==============================] - 127s 19ms/sample - loss: 0.0246 - acc: 0.9911 - val_loss: 1.2556 - val_acc: 0.7007
# Epoch 15/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0194 - acc: 0.9932
# Epoch 00015: val_loss did not improve from 0.86145
#
# Epoch 00015: val_acc improved from 0.73782 to 0.75174, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 125s 19ms/sample - loss: 0.0194 - acc: 0.9932 - val_loss: 1.0962 - val_acc: 0.7517
# Epoch 16/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0139 - acc: 0.9951
# Epoch 00016: val_loss did not improve from 0.86145
#
# Epoch 00016: val_acc did not improve from 0.75174
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0139 - acc: 0.9951 - val_loss: 1.2339 - val_acc: 0.7494
# Epoch 17/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0167 - acc: 0.9935
# Epoch 00017: val_loss did not improve from 0.86145
#
# Epoch 00017: val_acc did not improve from 0.75174
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0166 - acc: 0.9935 - val_loss: 1.5183 - val_acc: 0.7355
# Epoch 18/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0192 - acc: 0.9926
# Epoch 00018: val_loss did not improve from 0.86145
#
# Epoch 00018: val_acc improved from 0.75174 to 0.75638, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 124s 19ms/sample - loss: 0.0192 - acc: 0.9926 - val_loss: 1.3292 - val_acc: 0.7564
# Epoch 19/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0142 - acc: 0.9956
# Epoch 00019: val_loss did not improve from 0.86145
#
# Epoch 00019: val_acc improved from 0.75638 to 0.80278, saving model to /home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/modelFULL_acc.hdf5
# 6595/6595 [==============================] - 123s 19ms/sample - loss: 0.0142 - acc: 0.9956 - val_loss: 1.2431 - val_acc: 0.8028
# Epoch 20/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0103 - acc: 0.9962
# Epoch 00020: val_loss did not improve from 0.86145
#
# Epoch 00020: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0103 - acc: 0.9962 - val_loss: 1.3095 - val_acc: 0.7610
# Epoch 21/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0148 - acc: 0.9938
# Epoch 00021: val_loss did not improve from 0.86145
#
# Epoch 00021: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0148 - acc: 0.9938 - val_loss: 1.3938 - val_acc: 0.7448
# Epoch 22/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9964
# Epoch 00022: val_loss did not improve from 0.86145
#
# Epoch 00022: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0100 - acc: 0.9964 - val_loss: 1.4008 - val_acc: 0.7448
# Epoch 23/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0068 - acc: 0.9973
# Epoch 00023: val_loss did not improve from 0.86145
#
# Epoch 00023: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0068 - acc: 0.9973 - val_loss: 1.8037 - val_acc: 0.7262
# Epoch 24/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0157 - acc: 0.9939
# Epoch 00024: val_loss did not improve from 0.86145
#
# Epoch 00024: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0157 - acc: 0.9939 - val_loss: 1.4618 - val_acc: 0.7517
# Epoch 25/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0079 - acc: 0.9974
# Epoch 00025: val_loss did not improve from 0.86145
#
# Epoch 00025: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0079 - acc: 0.9974 - val_loss: 1.5822 - val_acc: 0.7517
# Epoch 26/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0060 - acc: 0.9976
# Epoch 00026: val_loss did not improve from 0.86145
#
# Epoch 00026: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0060 - acc: 0.9976 - val_loss: 1.6125 - val_acc: 0.7564
# Epoch 27/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9980
# Epoch 00027: val_loss did not improve from 0.86145
#
# Epoch 00027: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0054 - acc: 0.9979 - val_loss: 1.5291 - val_acc: 0.7541
# Epoch 28/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0058 - acc: 0.9970
# Epoch 00028: val_loss did not improve from 0.86145
#
# Epoch 00028: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0058 - acc: 0.9970 - val_loss: 1.3061 - val_acc: 0.7680
# Epoch 29/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9982
# Epoch 00029: val_loss did not improve from 0.86145
#
# Epoch 00029: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0045 - acc: 0.9982 - val_loss: 1.5980 - val_acc: 0.7610
# Epoch 30/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9980
# Epoch 00030: val_loss did not improve from 0.86145
#
# Epoch 00030: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0046 - acc: 0.9980 - val_loss: 1.5221 - val_acc: 0.7773
# Epoch 31/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0144 - acc: 0.9941
# Epoch 00031: val_loss did not improve from 0.86145
#
# Epoch 00031: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0144 - acc: 0.9941 - val_loss: 1.1806 - val_acc: 0.7564
# Epoch 32/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0107 - acc: 0.9959
# Epoch 00032: val_loss did not improve from 0.86145
#
# Epoch 00032: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0110 - acc: 0.9958 - val_loss: 1.4184 - val_acc: 0.7541
# Epoch 33/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0125 - acc: 0.9951
# Epoch 00033: val_loss did not improve from 0.86145
#
# Epoch 00033: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0125 - acc: 0.9951 - val_loss: 1.3953 - val_acc: 0.7494
# Epoch 34/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0058 - acc: 0.9967
# Epoch 00034: val_loss did not improve from 0.86145
#
# Epoch 00034: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0058 - acc: 0.9967 - val_loss: 1.3752 - val_acc: 0.7610
# Epoch 35/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0076 - acc: 0.9971
# Epoch 00035: val_loss did not improve from 0.86145
#
# Epoch 00035: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0076 - acc: 0.9971 - val_loss: 1.2883 - val_acc: 0.7587
# Epoch 36/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9980
# Epoch 00036: val_loss did not improve from 0.86145
#
# Epoch 00036: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0057 - acc: 0.9980 - val_loss: 1.3938 - val_acc: 0.7749
# Epoch 37/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0063 - acc: 0.9979
# Epoch 00037: val_loss did not improve from 0.86145
#
# Epoch 00037: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0063 - acc: 0.9979 - val_loss: 1.7135 - val_acc: 0.7494
# Epoch 38/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0068 - acc: 0.9974
# Epoch 00038: val_loss did not improve from 0.86145
#
# Epoch 00038: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0068 - acc: 0.9974 - val_loss: 1.8825 - val_acc: 0.7355
# Epoch 39/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0075 - acc: 0.9970
# Epoch 00039: val_loss did not improve from 0.86145
#
# Epoch 00039: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0075 - acc: 0.9970 - val_loss: 1.4525 - val_acc: 0.7796
# Epoch 40/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9982
# Epoch 00040: val_loss did not improve from 0.86145
#
# Epoch 00040: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0039 - acc: 0.9982 - val_loss: 1.6127 - val_acc: 0.7633
# Epoch 41/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9983
# Epoch 00041: val_loss did not improve from 0.86145
#
# Epoch 00041: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0043 - acc: 0.9983 - val_loss: 1.5081 - val_acc: 0.7657
# Epoch 42/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9974
# Epoch 00042: val_loss did not improve from 0.86145
#
# Epoch 00042: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0050 - acc: 0.9974 - val_loss: 1.5464 - val_acc: 0.7541
# Epoch 43/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0056 - acc: 0.9980
# Epoch 00043: val_loss did not improve from 0.86145
#
# Epoch 00043: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0056 - acc: 0.9980 - val_loss: 1.9797 - val_acc: 0.7169
# Epoch 44/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9977
# Epoch 00044: val_loss did not improve from 0.86145
#
# Epoch 00044: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0053 - acc: 0.9977 - val_loss: 1.5801 - val_acc: 0.7517
# Epoch 45/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9982
# Epoch 00045: val_loss did not improve from 0.86145
#
# Epoch 00045: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0057 - acc: 0.9982 - val_loss: 1.9238 - val_acc: 0.7309
# Epoch 46/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0058 - acc: 0.9976
# Epoch 00046: val_loss did not improve from 0.86145
#
# Epoch 00046: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 114s 17ms/sample - loss: 0.0058 - acc: 0.9976 - val_loss: 1.3160 - val_acc: 0.7726
# Epoch 47/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.9983
# Epoch 00047: val_loss did not improve from 0.86145
#
# Epoch 00047: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0038 - acc: 0.9983 - val_loss: 1.2882 - val_acc: 0.7796
# Epoch 48/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9982
# Epoch 00048: val_loss did not improve from 0.86145
#
# Epoch 00048: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0044 - acc: 0.9982 - val_loss: 1.4024 - val_acc: 0.7610
# Epoch 49/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.9986
# Epoch 00049: val_loss did not improve from 0.86145
#
# Epoch 00049: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0036 - acc: 0.9986 - val_loss: 1.5176 - val_acc: 0.7587
# Epoch 50/50
# 6585/6595 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9977
# Epoch 00050: val_loss did not improve from 0.86145
#
# Epoch 00050: val_acc did not improve from 0.80278
# 6595/6595 [==============================] - 113s 17ms/sample - loss: 0.0047 - acc: 0.9977 - val_loss: 1.6389 - val_acc: 0.7610

# %%
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/all_history", 'rb') as f:
    all_history = pickle.load(f)

# %%
## Plot results
print(len(all_history))

average_acc = [np.mean([x["acc"][i] for x in all_history]) for i in range(50)]
average_loss = [np.mean([x["loss"][i] for x in all_history]) for i in range(50)]
average_val_acc = [np.mean([x["val_acc"][i] for x in all_history]) for i in range(50)]
average_val_loss = [np.mean([x["val_loss"][i] for x in all_history]) for i in range(50)]

plt.plot(range(1, len(average_acc) + 1), average_acc, 'bo', label = 'Training acc')
plt.plot(range(1, len(average_val_acc) + 1), average_val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/acc_history')

plt.figure()

plt.plot(range(1, len(average_loss) + 1), average_loss, 'bo', label = 'Training loss')
plt.plot(range(1, len(average_val_loss) + 1), average_val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/loss_history')

plt.show()
# Out:
# 1

# %%
# #for i in range(0,10):
# print(np.argmax(all_history[0]['val_acc']))
# print(np.argmin(all_history[0]['val_loss']))
# print(max(all_history[0]['val_acc']))
# print(min(all_history[0]['val_loss']))
print(np.argmin(average_val_loss))
print(np.argmax(average_val_acc))
# Out:
# 1
# 18

# %%
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

def evaluate_model(k, confusion_matrices):

    train, validation, test = split_data(subjects_data=subjects_data, test_sub=None)
    validation_images = validation["images"]; validation_labels = validation["labels"]

    # Load best model from checkpoint of current fold
    model = load_model('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/modelsGEIs/model{}.hdf5'.format(k))
    
    # Check validation accuracy
    results = model.evaluate(validation_images, validation_labels)
    print(results)

    predictions = model.predict(validation_images)
    conf_mat = confusion_matrix(np.argmax(validation_labels, axis=1), np.argmax(predictions, axis=1))
    confusion_matrices.append(conf_mat)

# %%
confusion_matrices = Manager().list()
 
# Load best models of each fold and compute confusion matrices
p = Process(target=evaluate_model, args=('FULL_acc', confusion_matrices))
p.start()
p.join()

# Convert manager list back to normal list
conf_matrices = [item for item in confusion_matrices]

# Store list with confusion matrices from every fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/confusion_matrices_acc", 'wb') as f:
    pickle.dump(conf_matrices,f)

confusion_matrices = Manager().list()
 
# Load best models of each fold and compute confusion matrices
p = Process(target=evaluate_model, args=('FULL_loss', confusion_matrices))
p.start()
p.join()

# Convert manager list back to normal list
conf_matrices = [item for item in confusion_matrices]

# Store list with confusion matrices from every fold
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/confusion_matrices_loss", 'wb') as f:
    pickle.dump(conf_matrices,f)
# Out:
# Total samples:  7026
# 6595
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 431/431 [==============================] - 6s 14ms/sample - loss: 1.2431 - acc: 0.8028
# [1.2430604167988832, 0.8027842]
# Total samples:  7026
# 6595
# 431
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/pfa/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 431/431 [==============================] - 7s 15ms/sample - loss: 0.8614 - acc: 0.6613
# [0.8614491813593563, 0.6612529]

# %%
with open("/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/dataGEIs/confusion_matrices_loss", 'rb') as f:
    confusion_matrices = pickle.load(f)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Function to display confusion matrices
def DisplayCM(CM, title, save):

    display_labels = ['Diplegic', 'Hemiplegic', 'Neuropathic', 'Normal', 'Parkinson']
    fig, ax = plt.subplots(figsize=(10, 10))
    disp = ConfusionMatrixDisplay(confusion_matrix=CM,
                                display_labels=display_labels)
    disp = disp.plot(include_values=True,
                    cmap='viridis', ax=ax, xticks_rotation='horizontal')
    plt.title(title)
    plt.tight_layout()

    if save: plt.savefig('/home/pfa/Documents/Code/VGG19/Train_GAIT_IT_IST_FULL/Confusion Matrices GEIs/' + title)


# Initialize normalized and average CMs and normalized CMs list
cmAVG = np.zeros((5,5))
cmpercent = np.zeros((5,5))
cmpercentList = []

i = 1
# Create list for eachconfusion matrix in percentages
for cm in confusion_matrices:
    display_labels = ['Diplegic', 'Hemiplegic', 'Neuropathic', 'Normal', 'Parkinson']

    cmpercent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cmpercentList.append(cmpercent)


for i in range(0,5):
    for j in range(0,5):
        cmAVG[i][j] = np.mean([x[i][j] for x in cmpercentList])

# Plot average CM of current model
DisplayCM(CM=cmAVG, title='AVG_loss', save=True)

print(cmAVG)
print(np.mean([cmAVG[0][0],cmAVG[1][1], cmAVG[2][2], cmAVG[3][3], cmAVG[4][4]]))
# Out:
# [[0.18556701 0.43298969 0.13402062 0.02061856 0.22680412]
#  [0.02       0.67       0.28       0.         0.03      ]
#  [0.         0.13636364 0.86363636 0.         0.        ]
#  [0.         0.11764706 0.2745098  0.60784314 0.        ]
#  [0.02564103 0.00854701 0.00854701 0.         0.95726496]]
# 0.6568622936931002
